# %%
import cv2
import numpy as np
import struct
import time
import matplotlib.pyplot as plt
import os
import re
from pathlib import Path
import cv2

import matplotlib.patches as patches

from data_analysis.io.cine import read_cine, convert_cine_to_avi, overlay_motion_frames
from data_analysis.tracking.track_object import track_object_per_frame, get_chamber, update_tracking_result, show_tracking_results, delete_tracking_entry

# %%
tr_ifn = r"F:\AUG2025\P23\tracking_result.npy"
show_tracking_results(tr_ifn)

# %%
cine_path = r"E:\good_data\He3kA_B250G500G_pl0t20_uw15t35_P30\Y20241102_P30_z13_x200_y0@-40_022.cine"
avi_path = cine_path.replace('.cine', '.avi')

tarr, frarr, dt = read_cine(cine_path)

if not os.path.exists(avi_path):
    convert_cine_to_avi(frarr, avi_path)

# track_object(avi) was renamed to track_object_per_frame() and now returns a
# TrackingResult dataclass; it is tuple-unpackable into the same (positions,
# frame_numbers, center-crossing-frame) the old call returned.
result = track_object_per_frame(avi_path)
parr, frarr, cf = result

# %%
frame_num = cf
n_frames = 30   # half-window: overlay 2*n_frames + 1 frames

cx, cy, chamber_radius = get_chamber()

# Build the overlay
fig, ax = plt.subplots(figsize=(15, 5))
ax, overlay = overlay_motion_frames(frarr, center_frame=frame_num,step=10, n_frames=n_frames, ax=ax)

# overlay_motion_frames uses origin="lower"; flip the chamber circle's y to match
ax.add_patch(plt.Circle((cx, frarr.shape[1] - cy), chamber_radius,
                        fill=False, color='green', linewidth=2))

ax.set_title(f"t={tarr[frame_num] * 1e3:.3f}ms  ±{n_frames} frames")
ax.axis('off')

print(tarr[frame_num])

# %%
update_tracking_result(tr_ifn, cine_path, cf_new=1558, ct_new=-0.0442)
# update_tracking_result(tr_ifn, cine_path, cf_new=frame_num, ct_new=tarr[frame_num])

# %%
delete_tracking_entry(tr_ifn, r'F:\AUG2025\P24\27_He1kG430G_5800A_K-5_shot002.cine')

# %%
v = 9.8*np.sqrt(2*1/9.8) # velocity at center of chamber in m/s

t1 = 0.027 - tarr[cf]
t2 = 0.037 - tarr[cf]
print(t1)
print(t2)

x1 = v*t1 + 0.5*9.8*t1**2
x2 = v*t2 + 0.5*9.8*t2**2

print(x1)
print(x2)

# %%
tracking_dict = np.load(tr_ifn, allow_pickle=True).item()
prefixes = [os.path.basename(k)[:3] for k in tracking_dict.keys()]
shot_numbers = [int(os.path.basename(k).split('_shot')[1][:3]) for k in tracking_dict.keys()]
print(shot_numbers)
print(prefixes)

# %%
# Visual sanity check: overlay the hardcoded chamber on a real frame.
avi_path = r"E:\good_data\He3kA_B250G500G_pl0t20_uw15t35_P30\Y20241102_P30_z13_x200_y0@-10_026.avi"

cap = cv2.VideoCapture(avi_path)
ret, frame = cap.read()
cap.release()
assert ret, "Could not read frame"

cx, cy, r = get_chamber()
print(f"Hardcoded chamber: cx={cx} cy={cy} r={r}")

fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB), origin="upper")
circle = patches.Circle((cx, cy), r, fill=False, color="red", lw=2,
                         label=f"chamber: cx={cx} cy={cy} r={r}")
ax.add_patch(circle)
ax.legend()
ax.set_title("Red = hardcoded chamber — should sit on the bright chamber disk")
plt.tight_layout()
plt.show()

# %%
from data_analysis.tracking.track_object import get_ball_position_at_time, TrackingResult

# Reconstruct TrackingResult from the tuple-unpacked variables in cell-3
result = TrackingResult(positions=parr, frame_numbers=frarr, min_ydiff_frame=cf)

# Load calibration — adjust port tag to match your shot
calib = np.load(r"E:\calibration_factor_P30.npy", allow_pickle=True).item()
cm_per_px = calib["cm_per_px_mean"]
print(f"cm_per_px = {cm_per_px:.5f} cm/px")

# Spot-check: query at t0 and ±20 ms around it
t0_ms = tarr[cf] * 1000
print(f"\nt0 = {t0_ms:.3f} ms  (center-crossing frame {cf})")
for dt_ms in [-20, -10, 0, 10, 20]:
    pos = get_ball_position_at_time(t0_ms + dt_ms, result, tarr, cm_per_px)
    print(f"  t={t0_ms + dt_ms:8.3f} ms  ->  x={pos[0]:+.2f} cm,  y={pos[1]:+.2f} cm")

# Plot: linear fit (extended) vs tracked positions
t_tracked_ms = tarr[frarr] * 1000
x_cm_tracked = parr[:, 0] * cm_per_px
y_cm_tracked = parr[:, 1] * cm_per_px

margin_ms = 20
t_query = np.linspace(t_tracked_ms[0] - margin_ms, t_tracked_ms[-1] + margin_ms, 300)
xy = [get_ball_position_at_time(t, result, tarr, cm_per_px) for t in t_query]
x_fit = [p[0] for p in xy]
y_fit = [p[1] for p in xy]

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
for ax, tracked, fit, label in zip(
    axes,
    [x_cm_tracked, y_cm_tracked],
    [x_fit, y_fit],
    ["x (cm, rightward +)", "y (cm, upward +)"],
):
    ax.scatter(t_tracked_ms, tracked, s=12, zorder=3, label="tracked")
    ax.plot(t_query, fit, lw=1.5, label="linear fit (extended)")
    ax.axvline(t0_ms, color="r", ls="--", lw=1, label="t0 (center crossing)")
    ax.set_xlabel("t (ms)")
    ax.set_ylabel(label)
    ax.legend(fontsize=8)

axes[0].set_title("Horizontal position")
axes[1].set_title("Vertical position")
plt.suptitle(f"get_ball_position_at_time — cm/px={cm_per_px:.5f}", y=1.02)
plt.tight_layout()
plt.show()
