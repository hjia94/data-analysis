# %%
import sys
sys.path.insert(0, './Bdot_analysis')
import ReadScopeData as rd
import matplotlib.pyplot as plt
import numpy

# %matplotlib notebook

# %%
plt.figure()
ls = []

ifn = r"C:\data\epfl\C2--word.trc"
vol,tarr = rd.read_trc_data(ifn)
plt.plot(tarr, vol/5, '--', label='voltage/5')

ifn = r"C:\data\epfl\C3--word.trc"
vol,tarr = rd.read_trc_data(ifn)
plt.plot(tarr, vol, label='I1')
ls.append(numpy.max(vol))

ifn = r"C:\data\epfl\M4--word.trc"
vol,tarr = rd.read_trc_data(ifn)
plt.plot(tarr, vol, label='I2')
ls.append(numpy.max(vol))

ifn = r"C:\data\epfl\M2--word.trc"
vol,tarr = rd.read_trc_data(ifn)
plt.plot(tarr, vol, label='I3')
ls.append(numpy.max(vol))

ifn = r"C:\data\epfl\M1--word.trc"
vol,tarr = rd.read_trc_data(ifn)
plt.plot(tarr, vol, label='I4')
ls.append(numpy.max(vol))

ifn = r"C:\data\epfl\M3--word.trc"
vol,tarr = rd.read_trc_data(ifn)
plt.plot(tarr, vol, label='I5')
ls.append(numpy.max(vol))

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Reading data...
# Done
# Reading data...
# Done
# Reading data...
# Done
# Reading data...
# Done
# Reading data...
# Done
# Reading data...
# Done

# %%
arr1 = numpy.array([1,2,3,4,5])
plt.figure()
plt.scatter(arr1, ls)
# Out:
# <img src="data:image/png;base64,..." width="640">
